# %% [markdown]
# This is an attempt to recreate the Fig.2 of the PANS paper : "Neural heterogeneity controls computations in spiking neural networks"

# %%
import tvb

# %%
import inspect
from tvb.simulator.models import *

# List all the classes in the tvb.simulator.models module
models = [cls for cls, _ in inspect.getmembers(tvb.simulator.models, inspect.isclass)]
print(models)
# Out:
# ['CoombesByrne', 'CoombesByrne2D', 'DecoBalancedExcInh', 'DumontGutkin', 'Enum', 'Epileptor', 'Epileptor2D', 'EpileptorCodim3', 'EpileptorCodim3SlowMod', 'EpileptorRestingState', 'GastSchmidtKnosche_SD', 'GastSchmidtKnosche_SF', 'Generic2dOscillator', 'Hopfield', 'JansenRit', 'KIonEx', 'Kuramoto', 'LarterBreakspear', 'Linear', 'MPRDopa', 'Model', 'ModelsEnum', 'MontbrioPazoRoxin', 'ReducedSetFitzHughNagumo', 'ReducedSetHindmarshRose', 'ReducedWongWang', 'ReducedWongWangExcInh', 'SupHopf', 'WilsonCowan', 'ZerlautAdaptationFirstOrder', 'ZerlautAdaptationSecondOrder', 'ZetterbergJansen', '__class__']
